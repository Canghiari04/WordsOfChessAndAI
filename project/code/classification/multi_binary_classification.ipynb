# %% [markdown]
# __Obiettivo__
#
# Forzare la classificazione binaria secondo un approccio non-supervisionato, adeguando qualche algoritmo di similarità del testo.

# %%
import pandas

from nltk.corpus import stopwords

set_stopwords = set(stopwords.words("english"))

# %%
import json

with open("../../json/topics/topics.json", "r") as file:
    dict_topics = json.load(file)

df = pandas.read_json("../../json/dataset/dataset_preprocessed.json")

# %%
df.head(10)
# Out:
#                               DOI  \
# 2         10.1007/3-540-44595-1_3
# 5          10.3233/icg-1998-21203
# 7   10.1016/s0020-0255(99)00093-6
# 8          10.1006/ijhc.1999.0338
# 9   10.1016/s0020-0255(99)00097-3
# 11         10.1006/jpdc.1999.1600
# 12            10.1109/mc.2017.177
# 13      10.1017/s0140525x01003922
# 17   10.1037//0033-295x.107.3.578
# 18         10.1006/game.1999.0763
#
#                                                 Title  \
# 2            intelligent tutor web based chess course
# 5       learning play chess using temporal difference
# 7   temporal dierence learning heuristic search ga...
# 8            incremental acquisition search knowledge
# 9                   risk management game tree pruning
# 11       aphid asynchronous parallel game tree search
# 12             competition controversy computer chess
# 13  magical number short term memory reconsiderati...
# 17  expert adaptation representative task demand a...
# 18        chess like game dominance solvable two step
#
#                                              Keywords  \
# 2       [textbooks, chess, teachers, tutor, tutoring]
# 5         [td, knightcap, algorithm, internet, chess]
# 7   [backgammon, championship, algorithmic, td, ch...
# 8   [hampered, intractable, expert, intelligence, ...
# 9   [century, strategy, search, algorithm, algorit...
# 11  [search, synchronous, asynchronous, efficient,...
# 12                                               None
# 13     [memory, overload, evidence, seven, rehearsal]
# 17  [rejected, experts, critique, refutation, misr...
# 18  [solved, elimination, rounds, games, competitive]
#
#                                              Abstract  \
# 2   web based intelligent tutoring system try fill...
# 5   paper present tdleaf variation algorithm enabl...
# 7   temporal dierence learning natural method rein...
# 8   expert system nition address particular domain...
# 9   half century since minimax rst suggested strat...
# 11  parallel game tree search approach use synchro...
# 12
# 13  summarized evidence people remember seven chun...
# 17  theoretical framework long term working memory...
# 18  show strictly competitive nite game perfect in...
#
#                                          Introduction  \
# 2   course common way organize teaching high level...
# 5   temporal difference learning first introduced ...
# 7   central heuristic search whether single agent ...
# 8   early day arti cial intelligence strong emphas...
# 9   standard approach game tree search use improve...
# 11  making computer play game skillful manner comp...
# 12
# 13  one central contribution cognitive psychology ...
# 17  example chess player could play chess blindfol...
# 18         probably rst contribution pure game theory
#
#                                                  Text
# 2   web based intelligent tutoring system try fill...
# 5   paper present tdleaf variation algorithm enabl...
# 7   temporal dierence learning natural method rein...
# 8   expert system nition address particular domain...
# 9   half century since minimax rst suggested strat...
# 11  parallel game tree search approach use synchro...
# 12
# 13  summarized evidence people remember seven chun...
# 17  theoretical framework long term working memory...
# 18  show strictly competitive nite game perfect in...

# %%
list_topics = [topic for topic in dict_topics.keys()]

# %%
from typing import List, Dict
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

def preprocessed_topics(topics: str) -> List[str]:
    _list = []
    lemmatizer = WordNetLemmatizer()
    tokenizer = RegexpTokenizer(r"[a-zA-Z]+")

    for topic in topics:
        tokens = tokenizer.tokenize(topic.lower())

        tokens = [token for token in tokens if len(token) > 2]
        tokens = [token for token in tokens if token not in set_stopwords]

        lemma =  [lemmatizer.lemmatize(token) for token in tokens]
        
        _list.append(" ".join(lemma))

    return _list

def take_kwords_from_df(feature: str) -> List[str]:
    _list = []
    list_kwords: List[str]  = list(df[feature])

    for item in list_kwords:
        if item is not None:
            _list.append(" ".join(item))

    return _list

def take_feature_from_df(feature: str) -> Dict[str, str]:
    _dict = {}
    _df = df[["DOI", feature]]

    for _, value in _df.iterrows():
        if len(value[feature]) > 0:
            _dict[value["DOI"]] = value[feature]
            
    return _dict

topics = preprocessed_topics(list_topics)

kwords = take_kwords_from_df("Keywords")
dict_entities = take_feature_from_df("Abstract")

# %%
import json

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

_dict = {}
for key, value in dict_entities.items():
    dict_similarities = {}

    for topic in topics:
        corpus = [value, topic]
        vectorized_corpus = vectorizer.fit_transform(corpus)

        vectorized_text = vectorized_corpus[0]
        vectorized_topic = vectorized_corpus[1]

        similarity = cosine_similarity(vectorized_text, vectorized_topic)

        dict_similarities[topic] = similarity.max()

    _dict[key] = dict_similarities

# %%
with open("../../json/classification/classification_multi_binary.json", "w") as file:
    json.dump(_dict, file, indent=3)
