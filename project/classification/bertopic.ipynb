# %% [markdown]
# __Obiettivo__
#
# Classificare i contenuti estrapolati dai vari paper secondo una lista predefinita di topics.

# %%
import os 
import nltk

from dotenv import load_dotenv
from nltk.corpus import stopwords
from huggingface_hub import login

load_dotenv()

login(token=os.getenv("HUGGING_FACE_KEY"))

nltk.download("wordnet")
nltk.download("stopwords")
set_stopwords = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package wordnet to /home/matte/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/matte/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from typing import List

class Paper():
    def __init__(self, DOI: str, title: str, author: list[str], keyword: List[str], abstract: str, introduction: str):
        self.DOI = DOI
        self.title = title
        self.author = author
        self.keyword = keyword
        self.abstract = abstract
        self.introduction = introduction

    def __str__(self):
        return str(self.DOI) + " " + str(self.title)

# %%
import json

from typing import List

with open("../../json/grobid/data.json", "r") as file:
    _json = json.load(file)

list_paper: List[Paper] = []
for _dict in _json:
    for value in _dict.values():
        paper = Paper(value["DOI"], value["Title"], value["Author"], value["Keyword"], value["Abstract"],value["Introduction"])

        list_paper.append(paper)

# %%
import pandas

data = {
    "DOI": [paper.DOI for paper in list_paper],
    "Title": [paper.title for paper in list_paper],
    "Keywords": [paper.keyword for paper in list_paper],
    "Abstract": [paper.abstract for paper in list_paper],
    "Introduction": [paper.introduction for paper in list_paper]
}

df_cleaned = pandas.DataFrame(data=data).dropna(subset=["DOI", "Title", "Abstract"])
df_cleaned.head()
# Out:
#                              DOI  \
# 2        10.1007/3-540-44595-1_3
# 5         10.3233/icg-1998-21203
# 7  10.1016/s0020-0255(99)00093-6
# 8         10.1006/ijhc.1999.0338
# 9  10.1016/s0020-0255(99)00097-3
#
#                                                Title  \
# 2  An Intelligent Tutor for a Web-Based Chess Course
# 5  Learning To Play Chess Using Temporal Differences
# 7  Temporal dierence learning for heuristic searc...
# 8        Incremental acquisition of search knowledge
# 9               Risk management in game-tree pruning
#
#                                             Keywords  \
# 2      [textbooks, chess, teachers, tutor, tutoring]
# 5        [td, knightcap, algorithm, internet, chess]
# 7  [backgammon, championship, algorithmic, td, ch...
# 8  [hampered, intractable, expert, intelligence, ...
# 9  [century, strategy, search, algorithm, algorit...
#
#                                             Abstract  \
# 2  Web-based intelligent tutoring systems try to ...
# 5  In this paper we present TDLEAF( ), a variatio...
# 7  Temporal dierence (TD) learning is a natural m...
# 8  Expert systems by de"nition address a particul...
# 9  In the half century since minimax was ®rst sug...
#
#                                         Introduction
# 2  Courses are a common way to organize teaching ...
# 5  Temporal Difference learning, first introduced...
# 7  Central to all heuristic search, whether singl...
# 8  In its early days, arti"cial intelligence (AI)...
# 9  The standard approach to game-tree search is t...

# %%
from langdetect import detect
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from deep_translator import GoogleTranslator

lemmatizer = WordNetLemmatizer()
tokenizer = RegexpTokenizer(r"[a-zA-Z]+")

def preprocess_field(field: str) -> List[str]:
    try:
        if detect(field) != "en":
            field = GoogleTranslator(source="auto", target="en").translate(field)

        text = field.lower()
        tokens = tokenizer.tokenize(text)

        tokens = [token for token in tokens if len(token) > 2]
        tokens = [token for token in tokens if token not in set_stopwords]

        return [lemmatizer.lemmatize(token) for token in tokens]
    except Exception:
        return [" "]

# %%
preprocessed_data = {
    "DOI": [paper.DOI for paper in list_paper],
    "Title": [" ".join(preprocess_field(paper.title)) for paper in list_paper],
    "Keywords": [paper.keyword for paper in list_paper],
    "Abstract": [" ".join(preprocess_field(paper.abstract)) for paper in list_paper],
    "Introduction": [" ".join(preprocess_field(paper.introduction)) for paper in list_paper]
}

df_cleaned_preprocessed = pandas.DataFrame(data=preprocessed_data).dropna(subset=["DOI", "Title", "Abstract"])
df_cleaned_preprocessed.head()
# Out:
#                              DOI  \
# 2        10.1007/3-540-44595-1_3
# 5         10.3233/icg-1998-21203
# 7  10.1016/s0020-0255(99)00093-6
# 8         10.1006/ijhc.1999.0338
# 9  10.1016/s0020-0255(99)00097-3
#
#                                                Title  \
# 2           intelligent tutor web based chess course
# 5      learning play chess using temporal difference
# 7  temporal dierence learning heuristic search ga...
# 8           incremental acquisition search knowledge
# 9                  risk management game tree pruning
#
#                                             Keywords  \
# 2      [textbooks, chess, teachers, tutor, tutoring]
# 5        [td, knightcap, algorithm, internet, chess]
# 7  [backgammon, championship, algorithmic, td, ch...
# 8  [hampered, intractable, expert, intelligence, ...
# 9  [century, strategy, search, algorithm, algorit...
#
#                                             Abstract  \
# 2  web based intelligent tutoring system try fill...
# 5  paper present tdleaf variation algorithm enabl...
# 7  temporal dierence learning natural method rein...
# 8  expert system nition address particular domain...
# 9  half century since minimax rst suggested strat...
#
#                                         Introduction
# 2  course common way organize teaching high level...
# 5  temporal difference learning first introduced ...
# 7  central heuristic search whether single agent ...
# 8  early day arti cial intelligence strong emphas...
# 9  standard approach game tree search use improve...

# %%
df_cleaned_preprocessed["Text"] = df_cleaned_preprocessed["Abstract"] + " " + df_cleaned_preprocessed["Introduction"]
df_cleaned_preprocessed.head()
# Out:
#                              DOI  \
# 2        10.1007/3-540-44595-1_3
# 5         10.3233/icg-1998-21203
# 7  10.1016/s0020-0255(99)00093-6
# 8         10.1006/ijhc.1999.0338
# 9  10.1016/s0020-0255(99)00097-3
#
#                                                Title  \
# 2           intelligent tutor web based chess course
# 5      learning play chess using temporal difference
# 7  temporal dierence learning heuristic search ga...
# 8           incremental acquisition search knowledge
# 9                  risk management game tree pruning
#
#                                             Keywords  \
# 2      [textbooks, chess, teachers, tutor, tutoring]
# 5        [td, knightcap, algorithm, internet, chess]
# 7  [backgammon, championship, algorithmic, td, ch...
# 8  [hampered, intractable, expert, intelligence, ...
# 9  [century, strategy, search, algorithm, algorit...
#
#                                             Abstract  \
# 2  web based intelligent tutoring system try fill...
# 5  paper present tdleaf variation algorithm enabl...
# 7  temporal dierence learning natural method rein...
# 8  expert system nition address particular domain...
# 9  half century since minimax rst suggested strat...
#
#                                         Introduction  \
# 2  course common way organize teaching high level...
# 5  temporal difference learning first introduced ...
# 7  central heuristic search whether single agent ...
# 8  early day arti cial intelligence strong emphas...
# 9  standard approach game tree search use improve...
#
#                                                 Text
# 2  web based intelligent tutoring system try fill...
# 5  paper present tdleaf variation algorithm enabl...
# 7  temporal dierence learning natural method rein...
# 8  expert system nition address particular domain...
# 9  half century since minimax rst suggested strat...

# %%
import re

from typing import Dict

def extract_topics(path: str) -> Dict[str, str]:
    _dict = {}

    with open(path, "r") as _markdown:
        content = _markdown.read()

    labels = re.findall(r"[0-9].\s\**(.*\w)\**", content)

    for i in range(1, len(labels) + 1):
        sublabels = re.findall(fr"{i}.[0-9] \**(.*\w)\**", content)

        _dict[labels[i - 1]] = sublabels

    return _dict

topics = extract_topics("../../markdown/topics.md")

# %%
from sentence_transformers import SentenceTransformer

# List of predefined topics to use during the classification
list_zeroshot_topics = sum([item for item in topics.values()], [])

# Precalculating the embeddings
docs = list(df_cleaned.Abstract)
embedding_model = SentenceTransformer("all-mpnet-base-v2")

embeddings = embedding_model.encode(docs)

# %%
from bertopic import BERTopic

model = BERTopic(
    zeroshot_topic_list=list_zeroshot_topics,
    zeroshot_min_similarity=.6
)

_topics, _ = model.fit_transform(docs, embeddings=embeddings)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                      Name  \
# 0      -1    228                          -1_the_of_to_and
# 1       0     69                   0_search_the_minimax_of
# 2       1     66                    1_learning_to_of_games
# 3       2     53                           2_the_of_and_to
# 4       3     47                           3_and_the_to_of
# 5       4     42                 4_chess_skill_practice_in
# 6       5     36                            5_to_the_of_in
# 7       6     33        6_the_evolutionary_program_genetic
# 8       7     33                      7_parallel_the_to_on
# 9       8     31                8_women_men_in_differences
# 10      9     28                            9_de_les_la_et
# 11     10     27                           10_the_to_of_in
# 12     11     27                   11_chess_the_of_theorem
# 13     12     24                 12_cognitive_chess_the_in
# 14     13     24       13_memory_recall_positions_capacity
# 15     14     24            14_deep_blue_kasparov_computer
# 16     15     23                            15_gf_ih_uj_wf
# 17     16     19                 16_montecarlo_uct_mcts_go
# 18     17     18                       17_games_of_we_nash
# 19     18     17                  18_cheating_icga_and_the
# 20     19     16               19_students_chess_group_and
# 21     20     15         20_uncertainty_information_the_of
# 22     21     14            21_intelligence_systems_and_to
# 23     22     13             22_experts_positions_move_the
# 24     23     13                         23_that_of_it_and
# 25     24     12  24_retrograde_endgame_databases_analysis
#
#                                        Representation  \
# 0    [the, of, to, and, in, that, is, for, chess, we]
# 1   [search, the, minimax, of, is, tree, algorithm...
# 2   [learning, to, of, games, the, and, in, we, ga...
# 3   [the, of, and, to, is, chess, players, we, in,...
# 4   [and, the, to, of, with, system, is, user, for...
# 5   [chess, skill, practice, in, and, of, performa...
# 6   [to, the, of, in, knowledge, chess, this, is, ...
# 7   [the, evolutionary, program, genetic, of, func...
# 8   [parallel, the, to, on, of, hardware, and, fpg...
# 9   [women, men, in, differences, chess, players, ...
# 10      [de, les, la, et, du, des, en, le, plus, jeu]
# 11  [the, to, of, in, is, search, which, this, and...
# 12  [chess, the, of, theorem, tableaux, is, we, mi...
# 13  [cognitive, chess, the, in, and, of, brain, pl...
# 14  [memory, recall, positions, capacity, of, theo...
# 15  [deep, blue, kasparov, computer, match, the, c...
# 16           [gf, ih, uj, wf, dg, kf, 4c, kl, pm, ah]
# 17  [montecarlo, uct, mcts, go, with, tree, search...
# 18  [games, of, we, nash, game, equilibrium, theor...
# 19  [cheating, icga, and, the, rybka, plagiarism, ...
# 20  [students, chess, group, and, children, was, c...
# 21  [uncertainty, information, the, of, we, with, ...
# 22  [intelligence, systems, and, to, 3hirn, of, ch...
# 23  [experts, positions, move, the, fixations, exp...
# 24  [that, of, it, and, the, is, contents, models,...
# 25  [retrograde, endgame, databases, analysis, chi...
#
#                                   Representative_Docs
# 0   [In this paper a checkmate control procedure f...
# 1   [In game-playing programs relying on the minim...
# 2   [In this paper we present some experiments in ...
# 3   [Who is the best chess player of all time? Che...
# 4   [Although large displays could allow several u...
# 5   [Although it is widely acknowledged that chess...
# 6   [By developing an intelligent computer system ...
# 7   [Here, we propose an evolutionary algorithm (i...
# 8   [In this paper we will describe some of the ba...
# 9   [Only 1% of the world's chess grandmasters are...
# 10  [Jusqu'à ces dernières années, les théories le...
# 11  [The best chess programs have reached the top ...
# 12  [A chess tableau is a standard Young tableau i...
# 13  [We have studied the physiological consequence...
# 14  [For many years, the game of chess has provide...
# 15  [this very same conference, a young graduate s...
# 16  [08 42 R £8 EC D@ 4 9 F ©d ©e 0RU TH £f gd Dh ...
# 17  [The UCT algorithm learns a value function onl...
# 18  [Recently, the list of solved two-person zero-...
# 19  [The number of competitions using software age...
# 20  [Chess is thought to be a game demanding high ...
# 21  [Kriegspiel is a Chess variant similar to warg...
# 22  [Humans and computers have different strengths...
# 23  [The reported research extends classic finding...
# 24  [In this paper a number of principles for cont...
# 25  [Retrograde analysis is well-known and has bee...

# %% [markdown]
# _bart-large-mnli_ è un modello pre-addestrato realizzato per la classificazione secondo la tecnica Zero-Shot. Forniti in input una stringa e la lista di topics, il modello restituisce la probabilità di ciascuna etichetta rispetto al testo dato in input.
#
# Di seguito sono riportate le prove effettuate, i dati sono stati acquisiti da _df\_preprocessed\_cleaned_:
# - _Abstract_
# - _Text_
#
# Nota: i migliori score ottenuti sono stati raggiunti dall'impiego dei dati pre-processati e dalla lista di sub-topics ricavata dal .markdown

# %%
from transformers import pipeline

_model = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# Device set to use cpu

# %%
dois = list(df_cleaned_preprocessed.DOI)
docs = list(df_cleaned_preprocessed.Abstract)

dict_scores: Dict[str, Dict] = {}
for i in range(0, len(dois) - 1):
    if len(docs[i]) > 0:
        dict_classification = _model(docs[i], list_zeroshot_topics)
        dict_scores[dois[i]] = dict_classification

# %%
with open("../../json/topics/topics.json", "w") as file:
    json.dump(topics, file, indent=3)

with open("../../json/classification/bartScore.json", "w") as file:
    json.dump(dict_scores, file, indent=3)

with open("../../json/dataset/preprocessed_dataset.json", "w") as file:
    json.dump(df_cleaned_preprocessed.to_dict(), file, indent=3)
