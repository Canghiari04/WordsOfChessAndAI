# %% [markdown]
# __Obiettivo__
#
# Classificare i contenuti estrapolati dai vari paper secondo una lista predefinita di topics.

# %%
import os 
import nltk

from dotenv import load_dotenv
from nltk.corpus import stopwords
from huggingface_hub import login

load_dotenv()

login(token=os.getenv("HUGGING_FACE_KEY"))

nltk.download("wordnet")
nltk.download("stopwords")
set_stopwords = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package wordnet to /home/matte/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/matte/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from typing import List

class Paper():
    def __init__(self, DOI: str, title: str, author: list[str], keyword: List[str], abstract: str, introduction: str):
        self.DOI = DOI
        self.title = title
        self.author = author
        self.keyword = keyword
        self.abstract = abstract
        self.introduction = introduction

    def __str__(self):
        return str(self.DOI) + " " + str(self.title)

# %%
import json

from typing import List

with open("../../json/grobid/data.json", "r") as file:
    _json = json.load(file)

list_paper: List[Paper] = []
for _dict in _json:
    for value in _dict.values():
        paper = Paper(value["DOI"], value["Title"], value["Author"], value["Keyword"], value["Abstract"],value["Introduction"])

        list_paper.append(paper)

# %%
import pandas

data = {
    "DOI": [paper.DOI for paper in list_paper],
    "Title": [paper.title for paper in list_paper],
    "Keywords": [paper.keyword for paper in list_paper],
    "Abstract": [paper.abstract for paper in list_paper],
    "Introduction": [paper.introduction for paper in list_paper]
}

df_cleaned = pandas.DataFrame(data=data).dropna(subset=["DOI", "Title", "Abstract"])
df_cleaned.head()
# Out:
#                              DOI  \
# 2        10.1007/3-540-44595-1_3
# 5         10.3233/icg-1998-21203
# 7  10.1016/s0020-0255(99)00093-6
# 8         10.1006/ijhc.1999.0338
# 9  10.1016/s0020-0255(99)00097-3
#
#                                                Title  \
# 2  An Intelligent Tutor for a Web-Based Chess Course
# 5  Learning To Play Chess Using Temporal Differences
# 7  Temporal dierence learning for heuristic searc...
# 8        Incremental acquisition of search knowledge
# 9               Risk management in game-tree pruning
#
#                                             Keywords  \
# 2      [textbooks, chess, teachers, tutor, tutoring]
# 5        [td, knightcap, algorithm, internet, chess]
# 7  [backgammon, championship, algorithmic, td, ch...
# 8  [hampered, intractable, expert, intelligence, ...
# 9  [century, strategy, search, algorithm, algorit...
#
#                                             Abstract  \
# 2  Web-based intelligent tutoring systems try to ...
# 5  In this paper we present TDLEAF( ), a variatio...
# 7  Temporal dierence (TD) learning is a natural m...
# 8  Expert systems by de"nition address a particul...
# 9  In the half century since minimax was ®rst sug...
#
#                                         Introduction
# 2  Courses are a common way to organize teaching ...
# 5  Temporal Difference learning, first introduced...
# 7  Central to all heuristic search, whether singl...
# 8  In its early days, arti"cial intelligence (AI)...
# 9  The standard approach to game-tree search is t...

# %%
from langdetect import detect
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from deep_translator import GoogleTranslator

lemmatizer = WordNetLemmatizer()
tokenizer = RegexpTokenizer(r"[a-zA-Z]+")

def preprocess_field(field: str) -> List[str]:
    try:
        if detect(field) != "en":
            field = GoogleTranslator(source="auto", target="en").translate(field)

        text = field.lower()
        tokens = tokenizer.tokenize(text)

        tokens = [token for token in tokens if len(token) > 2]
        tokens = [token for token in tokens if token not in set_stopwords]

        return [lemmatizer.lemmatize(token) for token in tokens]
    except Exception:
        return [" "]

# %%
preprocessed_data = {
    "DOI": [paper.DOI for paper in list_paper],
    "Title": [preprocess_field(paper.title) for paper in list_paper],
    "Keywords": [paper.keyword for paper in list_paper],
    "Abstract": [" ".join(preprocess_field(paper.abstract)) for paper in list_paper],
    "Introduction": [" ".join(preprocess_field(paper.introduction)) for paper in list_paper]
}

df_cleaned_preprocessed = pandas.DataFrame(data=preprocessed_data).dropna(subset=["DOI", "Title", "Abstract"])
df_cleaned_preprocessed.head()
# Out:
#                              DOI  \
# 2        10.1007/3-540-44595-1_3
# 5         10.3233/icg-1998-21203
# 7  10.1016/s0020-0255(99)00093-6
# 8         10.1006/ijhc.1999.0338
# 9  10.1016/s0020-0255(99)00097-3
#
#                                                Title  \
# 2    [intelligent, tutor, web, based, chess, course]
# 5  [learning, play, chess, using, temporal, diffe...
# 7  [temporal, dierence, learning, heuristic, sear...
# 8      [incremental, acquisition, search, knowledge]
# 9            [risk, management, game, tree, pruning]
#
#                                             Keywords  \
# 2      [textbooks, chess, teachers, tutor, tutoring]
# 5        [td, knightcap, algorithm, internet, chess]
# 7  [backgammon, championship, algorithmic, td, ch...
# 8  [hampered, intractable, expert, intelligence, ...
# 9  [century, strategy, search, algorithm, algorit...
#
#                                             Abstract  \
# 2  web based intelligent tutoring system try fill...
# 5  paper present tdleaf variation algorithm enabl...
# 7  temporal dierence learning natural method rein...
# 8  expert system nition address particular domain...
# 9  half century since minimax rst suggested strat...
#
#                                         Introduction
# 2  course common way organize teaching high level...
# 5  temporal difference learning first introduced ...
# 7  central heuristic search whether single agent ...
# 8  early day arti cial intelligence strong emphas...
# 9  standard approach game tree search use improve...

# %%
import re

from typing import Dict

def extract_topics(path: str) -> Dict[str, str]:
    _dict = {}

    with open(path, "r") as _markdown:
        content = _markdown.read()

    labels = re.findall(r"[0-9].\s\**(.*\w)\**", content)

    for i in range(1, len(labels) + 1):
        sublabels = re.findall(fr"{i}.[0-9] \**(.*\w)\**", content)

        _dict[labels[i - 1]] = sublabels

    return _dict

topics = extract_topics("../../markdown/topics.md")

# %%
from sentence_transformers import SentenceTransformer

# List of predefined topics to use during the classification
list_zeroshot_topics = sum([item for item in topics.values()], [])

# Precalculating the embeddings
docs = list(df_cleaned.Abstract)
embedding_model = SentenceTransformer("all-mpnet-base-v2")

embeddings = embedding_model.encode(docs)

# %%
from bertopic import BERTopic

model = BERTopic(
    zeroshot_topic_list=list_zeroshot_topics,
    zeroshot_min_similarity=.6
)

topics, _ = model.fit_transform(docs, embeddings=embeddings)
# Out:
# /home/matte/Owner/WordsOfChessAndAI/venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/matte/Owner/WordsOfChessAndAI/venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/matte/Owner/WordsOfChessAndAI/venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/matte/Owner/WordsOfChessAndAI/venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                Name  \
# 0      -1    293                    -1_the_of_to_and
# 1       0     53           0_positions_memory_the_of
# 2       1     48                      1_the_to_of_in
# 3       2     47                     2_and_the_to_of
# 4       3     38           3_chess_skill_practice_in
# 5       4     36      4_learning_to_of_reinforcement
# 6       5     35  5_search_algorithm_trees_alphabeta
# 7       6     34  6_the_evolutionary_program_genetic
# 8       7     30                7_parallel_the_to_on
# 9       8     29        8_kriegspiel_player_games_of
# 10      9     27                      9_de_les_la_et
# 11     10     26            10_chess_the_of_tableaux
# 12     11     25           11_women_men_male_players
# 13     12     23           12_players_rating_elo_the
# 14     13     23                      13_gf_ih_uj_wf
# 15     14     21             14_cognitive_in_and_the
# 16     15     21         15_deep_blue_kasparov_match
# 17     16     20           16_montecarlo_uct_mcts_go
# 18     17     18             17_icc_cheating_and_the
# 19     18     16                18_go_selfplay_of_in
# 20     19     16         19_students_chess_group_and
# 21     20     15      20_intelligence_systems_and_to
# 22     21     13     21_minimax_heuristic_values_the
# 23     22     13           22_opening_of_choices_the
# 24     23     11   23_uncertainty_information_of_the
# 25     24     11                 24_to_search_the_of
# 26     25     10       25_book_opening_books_because
#
#                                        Representation  \
# 0    [the, of, to, and, in, we, that, is, chess, for]
# 1   [positions, memory, the, of, players, in, that...
# 2   [the, to, of, in, knowledge, is, and, this, an...
# 3   [and, the, to, of, with, system, is, user, int...
# 4   [chess, skill, practice, in, of, and, study, i...
# 5   [learning, to, of, reinforcement, games, that,...
# 6   [search, algorithm, trees, alphabeta, tree, th...
# 7   [the, evolutionary, program, genetic, of, func...
# 8   [parallel, the, to, on, of, hardware, and, che...
# 9   [kriegspiel, player, games, of, the, we, game,...
# 10      [de, les, la, et, du, des, en, le, plus, jeu]
# 11  [chess, the, of, tableaux, is, we, on, in, ger...
# 12  [women, men, male, players, in, chess, the, of...
# 13  [players, rating, elo, the, to, is, of, paired...
# 14           [gf, ih, uj, wf, dg, kf, 4c, kl, pm, ah]
# 15  [cognitive, in, and, the, brain, chess, activa...
# 16  [deep, blue, kasparov, match, computer, world,...
# 17  [montecarlo, uct, mcts, go, search, with, tree...
# 18  [icc, cheating, and, the, icga, rybka, plagiar...
# 19  [go, selfplay, of, in, the, artificial, game, ...
# 20  [students, chess, group, and, children, was, c...
# 21  [intelligence, systems, and, to, of, choice, 3...
# 22  [minimax, heuristic, values, the, evaluation, ...
# 23  [opening, of, choices, the, chess, we, and, mo...
# 24  [uncertainty, information, of, the, games, sup...
# 25  [to, search, the, of, moves, this, which, some...
# 26  [book, opening, books, because, chunker, the, ...
#
#                                   Representative_Docs
# 0   [The point of game tree search is to insulate ...
# 1   [This paper addresses empirically and theoreti...
# 2   [By developing an intelligent computer system ...
# 3   [Although large displays could allow several u...
# 4   [Although it is widely acknowledged that chess...
# 5   [In this paper we present some experiments in ...
# 6   [Many enhancements to the alpha-beta algorithm...
# 7   [Here, we propose an evolutionary algorithm (i...
# 8   [This paper proposes a distributed and scalabl...
# 9   [Kriegspiel is a chess variant similar to war ...
# 10  [Jusqu'à ces dernières années, les théories le...
# 11  [Chess has evolved over a span of about 2300 y...
# 12  [Only 1% of the world's chess grandmasters are...
# 13  [The increasing strength of chess engines and ...
# 14  [08 42 R £8 EC D@ 4 9 F ©d ©e 0RU TH £f gd Dh ...
# 15  [Superior cognitive performance can be viewed ...
# 16  [Garry Kasparov made two allegations of unfair...
# 17  [The UCT algorithm learns a value function onl...
# 18  [The number of competitions using software age...
# 19  [The game of chess is the most widely-studied ...
# 20  [Chess is thought to be a game demanding high ...
# 21  [Humans and computers have different strengths...
# 22  [Deeper searches in game-playing programs rely...
# 23  [Chess and chance are seemingly strange bedfel...
# 24  [Algorithms for equilibrium computation genera...
# 25  [Since early stages of computer game-playing, ...
# 26  [The best chess programs have reached the top ...
